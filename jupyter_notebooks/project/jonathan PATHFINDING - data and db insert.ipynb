# %%
import os
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import csv
import pymongo
from itertools import combinations
from collections import defaultdict

# %% [markdown]
# ## We import the various data files and recreate a single dataframe wich meets our needs

# %%
# 1
stops = pd.read_csv('/Users/jonathankhalifa/Desktop/T-AIA-901/PROJECT/data_sncf/stops.txt', sep=",", header=0)
stops = stops.drop('location_type', 1)
stops = stops.drop('stop_url', 1)
stops = stops.drop('zone_id', 1)
stops = stops.drop('stop_desc', 1)
stops = stops.drop('stop_lat', 1)
stops = stops.drop('stop_lon', 1)
stops['stop_id'] = stops['stop_id'].apply(lambda x: x[-8:])
#stops.head()


# 3
trips= pd.read_csv('/Users/jonathankhalifa/Desktop/T-AIA-901/PROJECT/data_sncf/trips.txt', sep=",", header=0)
trips = trips.drop('block_id', 1)
trips = trips.drop('shape_id', 1)
trips = trips.drop('direction_id', 1)
trips = trips.drop('service_id', 1)
#trips


# 4
stop_times= pd.read_csv('/Users/jonathankhalifa/Desktop/T-AIA-901/PROJECT/data_sncf/stop_times.txt', sep=",", header=0)
stop_times = stop_times.drop('shape_dist_traveled', 1)
stop_times = stop_times.drop('drop_off_type', 1)
stop_times = stop_times.drop('pickup_type', 1)
stop_times = stop_times.drop('stop_headsign', 1)
# keep 8 last digits from stop id col
stop_times['stop_id'] = stop_times['stop_id'].apply(lambda x: x[-8:])
#stop_times


# 5
routes= pd.read_csv('/Users/jonathankhalifa/Desktop/T-AIA-901/PROJECT/data_sncf/routes.txt', sep=",", header=0)
routes = routes.drop('agency_id', 1)
routes = routes.drop('route_desc', 1)
routes = routes.drop('route_url', 1)
routes = routes.drop('route_color', 1)
routes = routes.drop('route_text_color', 1)
routes = routes.drop('route_type', 1)
#routes.head()


pd.set_option('display.max_rows', 1000)

x = pd.merge(stop_times, trips, on='trip_id', how='outer')
x = pd.merge(stops, x, on='stop_id', how='outer')
x = x.sort_values(by=['trip_id','stop_sequence'])
x = x.drop_duplicates()
x = x[x['stop_sequence'].notna()]
x = x[~x.drop('parent_station', axis=1).duplicated(keep=False) | pd.notna(x['parent_station'])]
x = x.reset_index(drop=True)
x
# Out:
#          stop_id                   stop_name        parent_station  \
# 0       87413013            Gare de Le Havre  StopArea:OCE87413013
# 1       87413344  Gare de Bréauté-Beuzeville  StopArea:OCE87413344
# 2       87413385              Gare de Yvetot  StopArea:OCE87413385
# 3       87411017   Gare de Rouen-Rive-Droite  StopArea:OCE87411017
# 4       87384008     Gare de Paris-St-Lazare  StopArea:OCE87384008
# ...          ...                         ...                   ...
# 209255  87576165       Gare de Villeherviers  StopArea:OCE87576165
# 209256  87576157              Gare de Loreux  StopArea:OCE87576157
# 209257  87576140     Gare de Selles-St-Denis  StopArea:OCE87576140
# 209258  87576082    Gare de La Ferté-Imbault  StopArea:OCE87576082
# 209259  87543165             Gare de Salbris  StopArea:OCE87543165
#
#                        trip_id arrival_time departure_time  stop_sequence  \
# 0        OCESN003100F140147152     05:20:00       05:20:00            0.0
# 1        OCESN003100F140147152     05:35:00       05:36:00            1.0
# 2        OCESN003100F140147152     05:49:00       05:50:00            2.0
# 3        OCESN003100F140147152     06:12:00       06:15:00            3.0
# 4        OCESN003100F140147152     07:38:00       07:38:00            4.0
# ...                        ...          ...            ...            ...
# 209255  OCEZW861298F0200254332     19:42:00       19:42:00            9.0
# 209256  OCEZW861298F0200254332     19:46:00       19:46:00           10.0
# 209257  OCEZW861298F0200254332     19:53:00       19:54:00           11.0
# 209258  OCEZW861298F0200254332     19:58:00       19:59:00           12.0
# 209259  OCEZW861298F0200254332     20:09:00       20:09:00           13.0
#
#                        route_id  trip_headsign
# 0                    OCE1506035         3100.0
# 1                    OCE1506035         3100.0
# 2                    OCE1506035         3100.0
# 3                    OCE1506035         3100.0
# 4                    OCE1506035         3100.0
# ...                         ...            ...
# 209255  OCEZW-87543165-87576215       861298.0
# 209256  OCEZW-87543165-87576215       861298.0
# 209257  OCEZW-87543165-87576215       861298.0
# 209258  OCEZW-87543165-87576215       861298.0
# 209259  OCEZW-87543165-87576215       861298.0
#
# [209260 rows x 9 columns]

# %%
# TEST GET GROUP
xgrouped = x.groupby('trip_id')

b = xgrouped.get_group(list(xgrouped.groups)[0])
b
# Out:
#     stop_id                   stop_name        parent_station  \
# 0  87413013            Gare de Le Havre  StopArea:OCE87413013
# 1  87413344  Gare de Bréauté-Beuzeville  StopArea:OCE87413344
# 2  87413385              Gare de Yvetot  StopArea:OCE87413385
# 3  87411017   Gare de Rouen-Rive-Droite  StopArea:OCE87411017
# 4  87384008     Gare de Paris-St-Lazare  StopArea:OCE87384008
#
#                  trip_id arrival_time departure_time  stop_sequence  \
# 0  OCESN003100F140147152     05:20:00       05:20:00            0.0
# 1  OCESN003100F140147152     05:35:00       05:36:00            1.0
# 2  OCESN003100F140147152     05:49:00       05:50:00            2.0
# 3  OCESN003100F140147152     06:12:00       06:15:00            3.0
# 4  OCESN003100F140147152     07:38:00       07:38:00            4.0
#
#      route_id  trip_headsign
# 0  OCE1506035         3100.0
# 1  OCE1506035         3100.0
# 2  OCE1506035         3100.0
# 3  OCE1506035         3100.0
# 4  OCE1506035         3100.0

# %% [markdown]
#  <br/> <br/> <br/>
#  ## From each group, we get all possible trips and append them to an array. We remove duplicates , sort, calc the trip duration in seconds, and send to cloud DB.
#  #### example : Le havre -> Bréauté B , Le Havre -> Yvetot, Le Havre -> Rouen etc..

# %%
groups = x.groupby('trip_id')
yy = []

for group_name, group in xgrouped:

    group['arrival_time'] = pd.to_timedelta(group['arrival_time'])
    group['departure_time'] = pd.to_timedelta(group['departure_time'])

    comb = lambda x: [
        (x.loc[i1, 'stop_name'], x.loc[i2, 'stop_name'], 
        int((x.loc[i2, 'departure_time'] - x.loc[i1, 'arrival_time']).total_seconds()))
            for i1, i2 in combinations(x.index, 2)
    ]
    yyy = comb(group)
    for i in yyy:
            yy.append(i)


def removeDuplicates(lst):
    return [t for t in (set(tuple(i) for i in lst))]
          

ya = removeDuplicates(yy)

pp = []
for a in ya:
    l = list(a)
    l[0] = str(l[0])
    l[1] = str(l[1])
    l[2] = int(l[2])
    a = tuple(l)
    pp.append(a)


def Sort_Tuple(tup): 
    tup.sort(key = lambda x: x[0]) 
    return tup 
   
    
theList = Sort_Tuple(pp)
theList
# Out:
# [('Aboncourt', 'Alzing', 2640),
#  ('Aboncourt', 'Téterchen', 2940),
#  ('Aboncourt', 'Bouzonville', 1620),
#  ('Aboncourt', 'Metzeresche', 900),
#  ('Aboncourt', 'Merten-République', 3120),
#  ('Aboncourt', 'Budange', 180),
#  ('Aboncourt', 'Ebersviller (Centre)', 240),
#  ('Aboncourt', 'Freistroff', 1020),
#  ('Aboncourt', 'Bouzonville (Alzing)', 1740),
#  ('Aboncourt', 'Hargarten-Falck', 3600),
#  ('Aboncourt', 'Téterchen', 2340),
#  ('Aboncourt', 'Alzing', 2520),
#  ('Aboncourt', 'Metzervisse (Eglise)', 960),
#  ('Aboncourt', 'Merten-République', 3780),
#  ('Aboncourt', 'Falck (Rue principale)', 2640),
#  ('Aboncourt', 'Merten', 2940),
#  ('Aboncourt', 'Hestroff', 600),
#  ('Aboncourt', 'Yutz', 1800),
#  ('Aboncourt', 'Creutzwald G.R.', 3360),
#  ('Aboncourt', 'Metzervisse (Eglise)', 1140),
#  ('Aboncourt', 'Remelfang', 1200),
#  ('Aboncourt', 'Hargarten-aux-Mines', 2580),
#  ('Aboncourt', 'Kédange (Eglise)', 540),
#  ('Aboncourt', 'Brettnach', 2100),
#  ('Aboncourt', 'Brettnach', 2580),
#  ('Aboncourt', 'Yutz', 1980),
#  ('Aboncourt', 'Hargarten-aux-Mines', 2280),
#  ('Aboncourt', 'Merten', 4080),
#  ('Aboncourt', 'Freistroff', 1080),
#  ('Aboncourt', 'Brettnach', 1800),
#  ('Aboncourt', 'Téterchen', 3180),
#  ('Aboncourt', 'Remelfang', 1080),
#  ('Aboncourt', 'Anzeling', 720),
#  ('Aboncourt', 'Bouzonville (Alzing)', 1500),
#  ('Aboncourt', 'Anzeling (Carrefour)', 780),
#  ('Aboncourt', 'Metzervisse (Eglise)', 1200),
#  ('Aboncourt', 'Merten', 3960),
#  ('Aboncourt', 'Merten-République', 4020),
#  ('Aboncourt', 'Brettnach', 2940),
#  ('Aboncourt', 'Téterchen', 3060),
#  ('Aboncourt', 'Falck (Rue principale)', 2880),
#  ('Aboncourt', 'Kédange (Eglise)', 600),
#  ('Aboncourt', 'Vaudreching', 1260),
#  ('Aboncourt', 'Creutzwald G.R.', 3600),
#  ('Aboncourt', 'Metzervisse (Centre)', 1140),
#  ('Aboncourt', 'Hargarten-Falck', 2760),
#  ('Aboncourt', 'Gare de Thionville', 2460),
#  ('Aboncourt', 'Falck (Rue principale)', 3540),
#  ('Aboncourt', 'Hargarten-aux-Mines', 3300),
#  ('Aboncourt', 'Merten', 3840),
#  ('Aboncourt', 'Anzeling', 780),
#  ('Aboncourt', 'Merten-République', 3900),
#  ('Aboncourt', 'Brettnach', 2820),
#  ('Aboncourt', 'Hargarten-Falck', 2460),
#  ('Aboncourt', 'Gare de Thionville', 2160),
#  ('Aboncourt', 'Creutzwald G.R.', 4260),
#  ('Aboncourt', 'Anzeling (Carrefour)', 840),
#  ('Aboncourt', 'Gare de Thionville', 2640),
#  ('Aboncourt', 'Remelfang', 1320),
#  ('Aboncourt', 'Alzing', 1860),
#  ('Aboncourt', 'Hargarten-aux-Mines', 3180),
#  ('Aboncourt', 'Yutz-St-Vitus', 1920),
#  ('Aboncourt', 'Kuntzig (Place liberté)', 1560),
#  ('Aboncourt', 'Vaudreching', 1500),
#  ('Aboncourt', 'Metzervisse (Centre)', 900),
#  ('Aboncourt', 'Anzeling', 840),
#  ('Aboncourt', 'Distroff (Eglise)', 1200),
#  ('Aboncourt', 'Yutz-St-Vitus', 2100),
#  ('Aboncourt', 'Kuntzig (Place liberté)', 1740),
#  ('Aboncourt', 'Téterchen', 2040),
#  ('Aboncourt', 'Hombourg (Chapelle)', 360),
#  ('Aboncourt', 'Anzeling (Carrefour)', 900),
#  ('Aboncourt', 'Metzervisse (Centre)', 1080),
#  ('Aboncourt', 'Falck (Rue principale)', 3780),
#  ('Aboncourt', 'Hargarten-Falck', 3480),
#  ('Aboncourt', 'Hombourg (Tilleuls)', 420),
#  ('Aboncourt', 'Kédange', 600),
#  ('Aboncourt', 'Vaudreching', 1380),
#  ('Aboncourt', 'Ebersviller (Centre)', 300),
#  ('Aboncourt', 'Creutzwald G.R.', 4500),
#  ('Aboncourt', 'Alzing', 1620),
#  ('Aboncourt', 'Merten-République', 2880),
#  ('Aboncourt', 'Kuntzig (Bibiche)', 1440),
#  ('Aboncourt', 'Falck (Rue principale)', 3660),
#  ('Aboncourt', 'Hargarten-aux-Mines', 3420),
#  ('Aboncourt', 'Bouzonville', 1560),
#  ('Aboncourt', 'Metzeresche', 840),
#  ('Aboncourt', 'Hargarten-Falck', 3360),
#  ('Aboncourt', 'Distroff (Eglise)', 1260),
#  ('Aboncourt', 'Creutzwald G.R.', 4380),
#  ('Aboncourt', 'Kuntzig (Bibiche)', 1620),
#  ('Aboncourt', 'Alzing', 2760),
#  ('Aboncourt', 'Merten', 3180),
#  ('Aboncourt', 'Distroff (Eglise)', 1440),
#  ('Aboncourt', 'Hombourg (Tilleuls)', 480),
#  ('Aboncourt', 'Kédange', 660),
#  ('Aboncourt', 'Ebersviller (Centre)', 360),
#  ('Aboncourt', 'Bouzonville', 1440),
#  ('Aboncourt', 'Hestroff', 540),
#  ('Aboncourt', 'Kuntzig (Bibiche)', 1500),
#  ('Abrest Mairie', 'Pont-de-Dore-le-Chambon', 3360),
#  ('Abrest Mairie', 'Néronde', 3960),
#  ('Abrest Mairie', 'La-Croix-St-Bonnet', 1680),
#  ('Abrest Mairie', 'Gare de Vichy', 360),
#  ('Abrest Mairie', 'Mariol', 780),
#  ('Abrest Mairie', 'Courpière', 4320),
#  ('Abrest Mairie', 'Ris-Abris-Bus', 960),
#  ('Abrest Mairie', 'Olliergues', 5340),
#  ('Abrest Mairie', 'Vertolaye', 5940),
#  ('Abrest Mairie', 'Thiers-Lycée', 2220),
#  ('Abrest Mairie', 'Gare de Vichy', 420),
#  ('Abrest Mairie', 'St-Yorre-Nouvel-Hotel', 360),
#  ('Abrest Mairie', 'Ambert', 6780),
#  ('Abrest Mairie', 'Thiers-le-Moutier', 3000),
#  ('Abrest Mairie', 'Gare de Thiers', 2400),
#  ('Abrest Mairie', 'Gare de Pont-de-Dore', 3900),
#  ('Abrest Mairie', 'Gare de Pont-de-Dore', 3600),
#  ('Abrest Mairie', 'Thiers-Ville-Mairie', 2700),
#  ('Abrest Mairie', 'Puy-Guillaume-Emmaüs', 1500),
#  ('Abrest Mairie', 'Chauprillade-(La)', 1800),
#  ('Abrest Mairie', 'Puy-Guillaume-Ville', 1320),
#  ('Abrest Mairie', 'St-Yorre-Croix-des-Vern', 480),
#  ('Abrest Mairie', 'Giroux', 5040),
#  ('Abrest Mairie', 'Ambert-Ville', 6660),
#  ('Accolay-Le-Pont', 'Gare de Avallon', 2280),
#  ('Accolay-Le-Pont', 'Gare de Sermizelles-Vézelay', 1560),
#  ('Accolay-Le-Pont', 'Gare de Arcy-sur-Cure', 900),
#  ('Accolay-Le-Pont', 'Lucy-Sur-Cure-RD-606', 780),
#  ('Accolay-Le-Pont', 'Voutenay-/-Cure-Mairie', 1320),
#  ('Accolay-Le-Pont', 'Gare de Auxerre-St-Gervais', 1500),
#  ('Accolay-Le-Pont', 'Voutenay-/-Cure-Mairie', 1260),
#  ('Accolay-Le-Pont', 'Gare de Vermenton', 660),
#  ('Accolay-Le-Pont', 'Gare de Vincelles', 600),
#  ('Accolay-Le-Pont', 'Gare de Avallon', 2220),
#  ('Accolay-Le-Pont', 'Gare de Sermizelles-Vézelay', 1620),
#  ('Accolay-Le-Pont', 'Gare de Vermenton', 600),
#  ('Accolay-Le-Pont', 'Gare de Arcy-sur-Cure', 960),
#  ('Accolay-Le-Pont', 'Lucy-Sur-Cure-RD-606', 840),
#  ('Adamswiller Lot. forêt.', 'Alteckendorf-Eckendorf', 3420),
#  ('Adamswiller Lot. forêt.', 'Menchhoffen-(Abri)', 2340),
#  ('Adamswiller Lot. forêt.', 'Alteckendorf-Abri', 3060),
#  ('Adamswiller Lot. forêt.', 'Gare de Wingen-sur-Moder', 1380),
#  ('Adamswiller Lot. forêt.', 'Alteckendorf-Mairie', 3120),
#  ('Adamswiller Lot. forêt.', 'Gare de Diemeringen', 480),
#  ('Adamswiller Lot. forêt.', 'Alteckendorf-Eckendorf', 3180),
#  ('Adamswiller Lot. forêt.', 'Menchhoffen-(Abri)', 2100),
#  ('Adamswiller Lot. forêt.', 'Gare de Tieffenbach-Struth', 300),
#  ('Adamswiller Lot. forêt.', 'Alteckendorf-Abri', 3300),
#  ('Adamswiller Lot. forêt.', 'Gare de Wingen-sur-Moder', 1140),
#  ('Adamswiller Lot. forêt.', 'Adamswiller-(Mairie).', 60),
#  ('Adamswiller Lot. forêt.', 'Gare de Mommenheim', 3600),
#  ('Adamswiller Lot. forêt.', 'Minversheim-Rue-Princip', 3300),
#  ('Adamswiller Lot. forêt.', 'Ettendorf-Gare-Routière', 2940),
#  ('Adamswiller Lot. forêt.', 'Gare de Ingwiller', 2100),
#  ('Adamswiller Lot. forêt.', 'Gare de Obermodern', 2460),
#  ('Adamswiller Lot. forêt.', 'Wimmenau-(D919 R/Gar)', 1440),
#  ('Adamswiller Lot. forêt.', 'Gare de Mommenheim', 3840),
#  ('Adamswiller Lot. forêt.', 'Gare de Strasbourg', 5160),
#  ('Adamswiller Lot. forêt.', 'Minversheim-Rue-Princip', 3540),
#  ('Adamswiller Lot. forêt.', 'Ettendorf-Gare-Routière', 3180),
#  ('Adamswiller Lot. forêt.', 'Gare de Strasbourg', 5340),
#  ('Adamswiller Lot. forêt.', 'Col-De-Puberg', 780),
#  ('Adamswiller Lot. forêt.', 'Gare de Ingwiller', 1860),
#  ('Adamswiller Lot. forêt.', 'Frohmuhl- (Lavoir)', 480),
#  ('Adamswiller Lot. forêt.', 'Gare de Obermodern', 2700),
#  ('Adamswiller Lot. forêt.', 'Wimmenau-(D919 R/Gar)', 1680),
#  ('Adamswiller Lot. forêt.', 'Alteckendorf-Mairie', 3360),
#  ('Adamswiller-(Mairie).', 'Alteckendorf-Mairie', 3180),
#  ('Adamswiller-(Mairie).', 'Gare de Ingwiller', 1920),
#  ('Adamswiller-(Mairie).', 'Alteckendorf-Eckendorf', 3240),
#  ('Adamswiller-(Mairie).', 'Gare de Tieffenbach-Struth', 360),
#  ('Adamswiller-(Mairie).', 'Menchhoffen-(Abri)', 2160),
#  ('Adamswiller-(Mairie).', 'Gare de Diemeringen', 420),
#  ('Adamswiller-(Mairie).', 'Alteckendorf-Abri', 3360),
#  ('Adamswiller-(Mairie).', 'Gare de Wingen-sur-Moder', 1200),
#  ('Adamswiller-(Mairie).', 'Gare de Mommenheim', 3660),
#  ('Adamswiller-(Mairie).', 'Gare de Ingwiller', 2160),
#  ('Adamswiller-(Mairie).', 'Gare de Obermodern', 2520),
#  ('Adamswiller-(Mairie).', 'Wimmenau-(D919 R/Gar)', 1500),
#  ('Adamswiller-(Mairie).', 'Alteckendorf-Abri', 3120),
#  ('Adamswiller-(Mairie).', 'Gare de Wingen-sur-Moder', 1440),
#  ('Adamswiller-(Mairie).', 'Gare de Mommenheim', 3900),
#  ('Adamswiller-(Mairie).', 'Gare de Strasbourg', 5220),
#  ('Adamswiller-(Mairie).', 'Minversheim-Rue-Princip', 3600),
#  ('Adamswiller-(Mairie).', 'Gare de Obermodern', 2760),
#  ('Adamswiller-(Mairie).', 'Wimmenau-(D919 R/Gar)', 1740),
#  ('Adamswiller-(Mairie).', 'Ettendorf-Gare-Routière', 3240),
#  ('Adamswiller-(Mairie).', 'Gare de Strasbourg', 5400),
#  ('Adamswiller-(Mairie).', 'Col-De-Puberg', 840),
#  ('Adamswiller-(Mairie).', 'Frohmuhl- (Lavoir)', 540),
#  ('Adamswiller-(Mairie).', 'Alteckendorf-Mairie', 3420),
#  ('Adamswiller-(Mairie).', 'Minversheim-Rue-Princip', 3360),
#  ('Adamswiller-(Mairie).', 'Ettendorf-Gare-Routière', 3000),
#  ('Adamswiller-(Mairie).', 'Adamswiller Lot. forêt.', 60),
#  ('Adamswiller-(Mairie).', 'Alteckendorf-Eckendorf', 3480),
#  ('Adamswiller-(Mairie).', 'Menchhoffen-(Abri)', 2400),
#  ('Aguessac', 'Gare de Millau', 900),
#  ('Aguessac', 'La-Roquette-Hôt.-Rocade', 4200),
#  ('Aguessac', 'Gare de Millau', 600),
#  ('Aguessac', 'Gages-Mairie', 3900),
#  ('Aguessac', 'Recoules', 2400),
#  ('Aguessac', 'Gare de Sévérac-le-Château', 1800),
#  ('Aguessac', "Séverac-D'Aveyron-DeGau", 1500),
#  ('Aguessac', 'Lapanouse', 2100),
#  ('Aguessac', 'Onet-Le-Chateau-Bosch', 4320),
#  ('Aguessac', 'Gaillac-12-N88/D95', 2700),
#  ('Aguessac', 'Embranchement Grèzes', 3000),
#  ('Aguessac', 'Gare de Rodez', 4500),
#  ('Aguessac', 'Laissac-Foirail', 3180),
#  ('Aguessac', 'Hopital-Fenaille', 600),
#  ('Aguessac', 'Bertholène (Café Girou)', 3600),
#  ('Aiguebelette-Centre', 'Gare de St-André-le-Gaz', 2760),
#  ('Aiguebelette-Centre', 'Gare de Lépin-le-Lac-la-Bauche', 300),
#  ('Aiguebelette-Centre', 'Gare de St-Béron-la-Bridoire', 900),
#  ('Aiguebelette-Centre', 'Gare de Pont-de-Beauvoisin', 1440),
#  ('Aiguebelette-Centre', 'Domessin-le-Bonnard', 1200),
#  ('Aiguebelette-Centre', 'Gare de La Tour-du-Pin', 4740),
#  ('Aiguebelette-Centre', 'Gare de Chambéry-Chal.-les-Eaux', 1800),
#  ('Aiguebelette-Centre', 'Gare de Chambéry-Chal.-les-Eaux', 1500),
#  ('Aiguebelette-Centre', 'Domessin-le-Bonnard', 1140),
#  ('Aiguebelette-Centre', 'La Bridoire', 660),
#  ('Aiguebelette-Centre', 'La-Bridoire-Abris-Bus', 540),
#  ('Aiguebelette-Centre', 'Gare de Les Abrets-Fitilieu', 2280),
#  ('Aiguebelette-Centre', 'Gare de La Tour-du-Pin', 3660),
#  ('Aiguebelette-Centre', 'Les-Abrets-Rue-Italie', 2100),
#  ('Aigueblanche-Centre', 'Moutiers-Lycée', 240),
#  ('Aigueblanche-Centre', 'Gare de Moûtiers-Salins-Brides', 600),
#  ('Aigueblanche-Centre', 'La Bathie', 1380),
#  ('Aigueblanche-Centre', 'Gare de Albertville', 2460),
#  ('Aigueblanche-Centre', 'Petit-Coeur-la-Léchère', 180),
#  ('Aigueblanche-Centre', 'Gare de Moûtiers-Salins-Brides', 480),
#  ('Aigueblanche-Centre', 'St-Paul-College', 840),
#  ('Aigueblanche-Centre', 'Cévins-échangeur', 1020),
#  ('Aigueblanche-Centre', 'Gare de Notre-Dame-de-Briançon', 480),
#  ('Ailleville', 'Arsonval', 180),
#  ('Ailleville', 'Montaulin-vallée-Verte', 3600),
#  ('Ailleville', 'Bar-sur-Aube(Piscine)', 120),
#  ('Ailleville', 'Gare de Bar-sur-Aube', 300),
#  ('Ailleville', 'Vauchonvilliers-Mairie', 1320),
#  ('Ailleville', 'Juvancourt', 2940),
#  ('Ailleville', 'Daudes', 3840),
#  ('Ailleville', 'Gare de Vendeuvre (Aube)', 1800),
#  ('Ailleville', 'Rouilly-St-Loup-Guérade', 4320),
#  ('Ailleville', 'La Villeneuve-Ch.RN19', 2280),
#  ('Ailleville', 'Ville-sous-La-Ferté', 2760),
#  ('Ailleville', 'Montiéramey-Eglise', 2580),
#  ('Ailleville', 'Troyes(Bld 14 Juillet)', 5040),
#  ('Ailleville', 'Vauchonvilliers-Mairie', 1200),
#  ('Ailleville', 'Troyes-Victor-Hugo', 5160),
#  ('Ailleville', 'Rouilly-St-Loup-D21', 4140),
#  ('Ailleville', 'Jessains-Eglise', 900),
#  ('Ailleville', 'Bar-sur-Aube (HV)', 1320),
#  ('Ailleville', 'Forges-de-Clairvaux(Les', 2400),
#  ('Ailleville', 'St-Julien-Villas-Mairie', 4620),
#  ('Ailleville', 'Lusigny-sur-Barse RN19', 3240),
#  ('Ailleville', 'Vendeuvre-Centre', 1980),
#  ('Ailleville', 'Bayel-Eglise', 1980),
#  ('Ailleville', 'Lusigny-sur-Barse Centr', 3060),
#  ('Ailleville', 'Gare de Bar-sur-Aube', 180),
#  ('Ailleville', 'Bossancourt', 420),
#  ('Ailleville', 'Bar-sur-Aube(Hôpital)', 1560),
#  ('Ailleville', 'Le Ménilot', 2760),
#  ('Ailleville', 'Gare de Vendeuvre (Aube)', 1680),
#  ('Ailleville', 'Trannes', 660),
#  ('Ailleville', 'Magny-Fouchard', 1500),
#  ('Ailleville', 'Gare de Troyes', 5340),
#  ('Ailleville', 'Montaulin-Mairie', 3720),
#  ('Ailleville', 'Clairvaux D12', 2520),
#  ('Ailleville', 'Troyes-Quennedey', 4860),
#  ('Ailleville', 'Magny-Fouchard', 1380),
#  ('Aiton-Salle-Polyvalente', 'Gare de St-Avre-la-Chambre', 2160),
#  ('Aiton-Salle-Polyvalente', 'Saint-Étienne-de-Cuines', 2400),
#  ('Aiton-Salle-Polyvalente', 'Gare de St-Jean-de-Maurienne-A.', 3480),
#  ('Aiton-Salle-Polyvalente', 'Argentine-La-Combe', 720),
#  ('Aiton-Salle-Polyvalente', 'Argentine', 900),
#  ('Aiton-Salle-Polyvalente', 'Pontamafrey', 2880),
#  ('Aiton-Salle-Polyvalente', "Gare de St-Pierre-d'Albigny", 780),
#  ('Aiton-Salle-Polyvalente', "Gare de St-Pierre-d'Albigny", 960),
#  ('Aiton-Salle-Polyvalente', 'La-Chambre', 2100),
#  ('Aiton-Salle-Polyvalente', 'Gare de Epierre-St-Léger', 1380),
#  ('Aiton-Salle-Polyvalente', 'Argentine', 1020),
#  ('Aiton-Salle-Polyvalente', 'Les Chavannes-St-Rémy', 1860),
#  ('Aiton-Salle-Polyvalente', 'Gare de Aiguebelle', 480),
#  ('Aiton-Salle-Polyvalente', 'Argentine-Gemelly', 660),
#  ('Aiton-Salle-Polyvalente', 'Argentine-Gemelly', 840),
#  ('Aiton-Salle-Polyvalente', 'Gare de Chamousset', 300),
#  ('Aix-Gare-Routière', 'Gare de Gardanne', 1200),
#  ('Aix-Gare-Routière', 'Gare de Marseille-St-Charles', 2400),
#  ('Ajain', 'Gare de Montluçon-Ville', 3360),
#  ('Ajain', 'Gouzon-Champ-de-Foire', 1260),
#  ('Ajain', 'Gare de Guéret', 660),
#  ('Ajain', 'Gare de Parsac-Gouzon', 720),
#  ('Alba-Ruines-Romaines', 'Le-Teil-Sablons', 600),
#  ('Alba-Ruines-Romaines', 'St-Jean-Centenier-Ctr', 300),
#  ('Alba-Ruines-Romaines', 'Grenoble-Champollion', 7620),
#  ('Alba-Ruines-Romaines', 'Aubenas-Gare-Routière', 1800),
#  ('Alba-Ruines-Romaines', 'Villeneuve-de-Berg-Cent', 900),
#  ('Alba-Ruines-Romaines', 'Aubenas-Pl.-de-la-Paix', 2100),
#  ('Alba-Ruines-Romaines', 'Montélimar-G-Routière', 2100),
#  ('Alba-Ruines-Romaines', 'Gare de Valence-TGV', 5700),
#  ('Alba-Ruines-Romaines', "St-Martin-d'Hères", 8820),
#  ('Alba-Ruines-Romaines', 'Grenoble-Gare-Routière', 7200),
#  ('Alba-Ruines-Romaines', 'Grenoble-Gare-Routière', 9600),
#  ('Alba-Ruines-Romaines', 'Gare de Lavilledieu', 1380),
#  ('Albias-Abri-Bus', 'Gare de Cahors', 3960),
#  ('Albias-Abri-Bus', 'Gare de Brive-la-Gaillarde', 11160),
#  ('Albias-Abri-Bus', 'Gare de Gourdon', 6960),
#  ('Albias-Abri-Bus', 'Gare de Souillac', 9060),
#  ('Albias-Abri-Bus', 'Gare de Lalbenque-Fontanes', 3060),
#  ('Albias-Abri-Bus', 'Gare de Montauban-Ville-Bourbon', 1560),
#  ('Albias-Abri-Bus', 'Gare de Caussade (T.-et-G.)', 1260),
#  ('Albigny-Neuville-Arret', 'Collonges-F.-Tcl-Gar', 600),
#  ('Albigny-Neuville-Arret', 'Lyon-Perrache-Gare-Rout', 2400),
#  ('Albigny-Neuville-Arret', 'Lyon-Vaise-Gare-Routièr', 1500),
#  ('Albigny-Neuville-Arret', "Couzon-Au-Mont-D'or-Arr", 300),
#  ('Alet-les-Bains', 'Couiza-Ste-Anne', 480),
#  ('Alet-les-Bains', 'Couiza-Montazels', 660),
#  ('Alet-les-Bains', 'Gare de Carcassonne', 3960),
#  ('Alet-les-Bains', 'Pomas-Lavoir', 1680),
#  ('Alet-les-Bains', 'Pomas-Lavoir', 2160),
#  ('Alet-les-Bains', 'Gare de Limoux-Flassian', 840),
#  ('Alet-les-Bains', 'Gare de Limoux', 600),
#  ('Alet-les-Bains', 'Pomas-Lavoir', 1860),
#  ('Alet-les-Bains', 'Esperaza', 960),
#  ('Alet-les-Bains', 'Couiza-Ste-Anne', 540),
#  ('Alet-les-Bains', 'Gare de Limoux', 780),
#  ('Alet-les-Bains', 'Gare de Limoux-Flassian', 1200),
#  ('Alet-les-Bains', 'Campagne-sur-Aude-Pont', 1260),
#  ('Alet-les-Bains', 'Gare de Limoux-Flassian', 900),
#  ('Alet-les-Bains', 'Esperaza', 1020),
#  ('Alet-les-Bains', 'Gare de Limoux', 540),
#  ('Alet-les-Bains', 'Campagne-sur-Aude-Pont', 1320),
#  ('Alet-les-Bains', 'Gare de Carcassonne', 3300),
#  ('Alet-les-Bains', 'Gare de Limoux-Flassian', 960),
#  ('Alet-les-Bains', 'Gare de Limoux', 720),
#  ('Alet-les-Bains', 'Esperaza', 1080),
#  ('Alet-les-Bains', 'Gare de Limoux-Flassian', 1140),
#  ('Alet-les-Bains', 'Gare de Limoux', 900),
#  ('Alet-les-Bains', 'Quillan', 1620),
#  ('Alet-les-Bains', 'Quillan', 2100),
#  ('Alet-les-Bains', 'Campagne-sur-Aude-Pont', 1380),
#  ('Alet-les-Bains', 'Quillan', 1800),
#  ('Alet-les-Bains', 'Gare de Limoux-Flassian', 1500),
#  ('Alet-les-Bains', 'Quillan', 1500),
#  ('Alet-les-Bains', 'Pomas-Lavoir', 1560),
#  ('Alet-les-Bains', 'Couiza-Montazels', 720),
#  ('Alet-les-Bains', 'Quillan', 1860),
#  ('Alet-les-Bains', 'Couiza-Montazels', 600),
#  ('Alet-les-Bains', 'Gare de Carcassonne', 3900),
#  ('Alet-les-Bains', 'Gare de Carcassonne', 3600),
#  ('Alet-les-Bains', 'Couiza-Ste-Anne', 600),
#  ('Allamps-Esat', 'Toul-Gare-Routière', 1500),
#  ('Allamps-Esat', 'Blénod-lès-Toul-Les-Nau', 780),
#  ('Allamps-Esat', 'Barisey-la-Côte Mairie', 300),
#  ('Allamps-Esat', 'Bulligny-Centre', 480),
#  ('Allamps-Esat', 'Gare de Toul', 1800),
#  ('Allamps-Esat', 'Barisey-la-Côte', 180),
#  ('Allanche', 'Ste-Anastasie', 600),
#  ('Allanche', 'Feniers', 1380),
#  ('Allanche', 'Marcenat', 900),
#  ('Allanche', 'Condat', 1560),
#  ('Allanche', 'Riom_Es_M_la_Poste.', 2940),
#  ('Allanche', 'Landeyrat', 540),
#  ('Allanche', 'Riom-es-Montagne-Cliniq', 2880),
#  ('Allanche', 'Gare de Neussargues', 1320),
#  ('Allanche', 'vely', 1560),
#  ('Allanche', 'St-Amandin', 2220),
#  ('Allegre-Maison-Retraite', 'Gare de Darsac', 840),
#  ('Allegre-Maison-Retraite', 'Allègre', 60),
#  ('Allegre-Maison-Retraite', "Céaux-d'Allègre", 420),
#  ('Allegre-Maison-Retraite', 'Le Puy-en-Velay Lafayette', 2760),
#  ('Allegre-Maison-Retraite', 'La Chaise-Dieu', 960),
#  ('Allegre-Maison-Retraite', 'Gare de Le Puy-en-Velay', 2640),
#  ('Allegre-Maison-Retraite', 'Arlanc-Place-Eglise', 1560),
#  ('Allegre-Maison-Retraite', 'Darsac-Lotissement', 1200),
#  ('Allegre-Maison-Retraite', 'Gare de Le Puy-en-Velay', 3000),
#  ('Allegre-Maison-Retraite', 'Coubladour', 1440),
#  ('Allegre-Maison-Retraite', "Céaux-d'Allègre", 480),
#  ('Allegre-Maison-Retraite', 'Gare de Darsac', 1080),
#  ('Allegre-Maison-Retraite', 'La Chaise-Dieu', 1020),
#  ('Allegre-Maison-Retraite', 'Le Puy-Lafayette', 2700),
#  ('Allegre-Maison-Retraite', 'La Chaise-Dieu', 900),
#  ('Allegre-Maison-Retraite', 'Freyssenet', 1020),
#  ('Allegre-Maison-Retraite', 'Le Puy-Lafayette', 2400),
#  ('Allegre-Maison-Retraite', 'Monlet', 300),
#  ('Allegre-Maison-Retraite', 'Ambert-Ville', 2340),
#  ('Allegre-Maison-Retraite', 'Coubladour', 1500),
#  ('Allegre-Maison-Retraite', 'Le Puy-en-Velay-Hermit.', 2520),
#  ('Allegre-Maison-Retraite', 'Serres-Hte-Loire', 180),
#  ('Allegre-Maison-Retraite', 'Coubladour', 1200),
#  ('Allegre-Maison-Retraite', 'Le-Puy-en-Velay-Fayolle', 2520),
#  ('Allegre-Maison-Retraite', 'Puy-en-Velay-Hopital', 2640),
#  ('Allegre-Maison-Retraite', 'Le Puy-Lafayette', 2760),
#  ('Allegre-Maison-Retraite', 'Ambert', 2580),
#  ('Allegre-Maison-Retraite', 'Puy-en-Velay-Hopital', 2340),
#  ('Allegre-Maison-Retraite', 'Le Puy-en-Velay-Hermit.', 2580),
#  ('Allegre-Maison-Retraite', 'Marsac-en-Livradois', 1920),
#  ('Allegre-Maison-Retraite', 'Puy-en-Velay-Hopital', 2700),
#  ('Allegre-Maison-Retraite', 'Darsac-Lotissement', 900),
#  ('Allegre-Maison-Retraite', 'Sembadel', 720),
#  ('Allegre-Maison-Retraite', 'Dore-Eglise', 1440),
#  ('Allegre-Maison-Retraite', 'Freyssenet', 1320),
#  ('Allegre-Maison-Retraite', 'Freycenet', 1320),
#  ('Allegre-Maison-Retraite', 'Freycenet', 1020),
#  ('Allegre-Maison-Retraite', 'Le Puy-en-Velay Lafayette', 2700),
#  ('Allegre-Maison-Retraite', 'Allègre', 180),
#  ('Allegre-Maison-Retraite', 'Le-Puy-en-Velay-Fayolle', 2820),
#  ('Allegre-Maison-Retraite', 'Le Puy-en-Velay Lafayette', 2400),
#  ('Allègre', 'Arlanc-Place-Eglise', 1500),
#  ('Allègre', 'Freycenet', 1080),
#  ('Allègre', 'Sembadel', 660),
#  ('Allègre', 'Serres-Hte-Loire', 240),
#  ('Allègre', 'Dore-Eglise', 1380),
#  ('Allègre', 'Le-Puy-en-Velay-Fayolle', 2880),
#  ('Allègre', 'Le Puy-en-Velay Lafayette', 2460),
#  ('Allègre', 'Gare de Darsac', 900),
#  ('Allègre', 'Puy-en-Velay-Hopital', 2700),
#  ('Allègre', 'Sembadel', 540),
#  ('Allègre', "Céaux-d'Allègre", 480),
#  ('Allègre', 'Le Puy-en-Velay Lafayette', 2820),
#  ('Allègre', 'Gare de Le Puy-en-Velay', 2700),
#  ('Allègre', 'Allegre-Maison-Retraite', 60),
#  ('Allègre', 'Ambert', 2520),
#  ('Allègre', 'Darsac-Lotissement', 1260),
#  ('Allègre', 'Gare de Le Puy-en-Velay', 3060),
#  ('Allègre', 'Gare de Darsac', 1140),
#  ('Allègre', 'Darsac-Lotissement', 960),
#  ('Allègre', "Céaux-d'Allègre", 540),
#  ('Allègre', 'Freycenet', 1380),
#  ('Allègre', 'La Chaise-Dieu', 780),
#  ('Allègre', 'Le Puy-Lafayette', 2760),
#  ('Allègre', 'Le Puy-en-Velay Lafayette', 2760),
#  ('Allègre', 'La Chaise-Dieu', 960),
#  ('Allègre', 'Freyssenet', 1080),
#  ('Allègre', 'Le Puy-Lafayette', 2460),
#  ('Allègre', 'Coubladour', 1560),
#  ('Allègre', 'Le Puy-en-Velay-Hermit.', 2580),
#  ('Allègre', 'Coubladour', 1260),
#  ('Allègre', 'La Chaise-Dieu', 840),
#  ('Allègre', 'Le-Puy-en-Velay-Fayolle', 2580),
#  ('Allègre', 'Monlet', 240),
#  ('Allègre', 'Ambert-Ville', 2280),
#  ('Allègre', 'Le Puy-Lafayette', 2820),
#  ('Allègre', 'Puy-en-Velay-Hopital', 2400),
#  ('Allègre', 'Le Puy-en-Velay-Hermit.', 2640),
#  ('Allègre', 'Monlet', 120),
#  ('Allègre', 'Puy-en-Velay-Hopital', 2760),
#  ('Allègre', 'Coubladour', 1500),
#  ('Allègre', 'Marsac-en-Livradois', 1860),
#  ('Allègre', 'Freyssenet', 1380),
#  ('Alteckendorf-Abri', 'Minversheim-Rue-Princip', 240),
#  ('Alteckendorf-Abri', 'Buswiller-Eglise', 480),
#  ('Alteckendorf-Abri', "Ettendorf-Pl,-de-L'ecol", 240),
#  ('Alteckendorf-Abri', 'Bouxwiller-Babenhausen', 1140),
#  ('Alteckendorf-Abri', 'Buswiller-Eglise', 360),
#  ('Alteckendorf-Abri', 'Alteckendorf-Mairie', 60),
#  ('Alteckendorf-Abri', 'Gare de Mommenheim', 660),
#  ('Alteckendorf-Abri', 'Buswiller-Eglise', 420),
#  ('Alteckendorf-Abri', 'Alteckendorf-Eckendorf', 120),
#  ('Alteckendorf-Abri', "Ettendorf-Pl,-de-L'ecol", 180),
#  ('Alteckendorf-Abri', 'Gare de Mommenheim', 540),
#  ('Alteckendorf-Abri', 'Gare de Mommenheim', 720),
#  ('Alteckendorf-Abri', 'Ettendorf-(Angle-Pont)', 240),
#  ('Alteckendorf-Abri', 'Gare de Strasbourg', 2040),
#  ('Alteckendorf-Abri', 'Ettendorf-Gare-Routière', 120),
#  ('Alteckendorf-Abri', 'Gare de Strasbourg', 2100),
#  ('Alteckendorf-Abri', 'Ettendorf-(Angle-Pont)', 180),
#  ('Alteckendorf-Eckendorf', 'Buswiller-Eglise', 600),
#  ('Alteckendorf-Eckendorf', "Ettendorf-Pl,-de-L'ecol", 360),
#  ('Alteckendorf-Eckendorf', 'Gare de Mommenheim', 540),
#  ('Alteckendorf-Eckendorf', 'Bouxwiller-Babenhausen', 1260),
#  ('Alteckendorf-Eckendorf', 'Alteckendorf-Abri', 120),
#  ('Alteckendorf-Eckendorf', 'Buswiller-Eglise', 480),
#  ('Alteckendorf-Eckendorf', 'Gare de Mommenheim', 420),
#  ('Alteckendorf-Eckendorf', 'Gare de Mommenheim', 600),
#  ('Alteckendorf-Eckendorf', 'Ettendorf-(Angle-Pont)', 300),
#  ('Alteckendorf-Eckendorf', 'Gare de Strasbourg', 1920),
#  ('Alteckendorf-Eckendorf', 'Buswiller-Eglise', 540),
#  ('Alteckendorf-Eckendorf', 'Ettendorf-(Angle-Pont)', 360),
#  ('Alteckendorf-Eckendorf', 'Gare de Strasbourg', 1980),
#  ('Alteckendorf-Eckendorf', 'Minversheim-Rue-Princip', 120),
#  ('Alteckendorf-Eckendorf', 'Ettendorf-Gare-Routière', 240),
#  ('Alteckendorf-Eckendorf', 'Alteckendorf-Mairie', 60),
#  ('Alteckendorf-Eckendorf', "Ettendorf-Pl,-de-L'ecol", 300),
#  ('Alteckendorf-Mairie', 'Minversheim-Rue-Princip', 180),
#  ('Alteckendorf-Mairie', 'Gare de Strasbourg', 1980),
#  ('Alteckendorf-Mairie', 'Buswiller-Eglise', 480),
#  ('Alteckendorf-Mairie', "Ettendorf-Pl,-de-L'ecol", 240),
#  ('Alteckendorf-Mairie', 'Buswiller-Eglise', 540),
#  ('Alteckendorf-Mairie', "Ettendorf-Pl,-de-L'ecol", 300),
#  ('Alteckendorf-Mairie', 'Alteckendorf-Eckendorf', 60),
#  ('Alteckendorf-Mairie', 'Alteckendorf-Abri', 60),
#  ('Alteckendorf-Mairie', 'Gare de Mommenheim', 480),
#  ('Alteckendorf-Mairie', 'Gare de Mommenheim', 660),
#  ('Alteckendorf-Mairie', 'Ettendorf-Gare-Routière', 180),
#  ('Alteckendorf-Mairie', 'Ettendorf-(Angle-Pont)', 240),
#  ('Alteckendorf-Mairie', 'Gare de Strasbourg', 2040),
#  ('Alteckendorf-Mairie', 'Gare de Mommenheim', 600),
#  ('Alteckendorf-Mairie', 'Bouxwiller-Babenhausen', 1200),
#  ('Alteckendorf-Mairie', 'Ettendorf-(Angle-Pont)', 300),
#  ('Alteckendorf-Mairie', 'Buswiller-Eglise', 420),
#  ('Alzing', 'Bouzonville', 540),
#  ('Alzing', 'Anzeling', 1020),
#  ('Alzing', 'Yutz-St-Vitus', 4620),
#  ('Alzing', 'Brettnach', 60),
#  ('Alzing', 'Metzervisse (Eglise)', 3660),
#  ('Alzing', 'Gare de Thionville', 4260),
#  ('Alzing', 'Merten-République', 1260),
#  ('Alzing', 'Kédange (Eglise)', 3540),
#  ('Alzing', 'Anzeling', 1200),
#  ('Alzing', 'Brettnach', 240),
#  ('Alzing', 'Kédange', 3600),
#  ('Alzing', 'Kuntzig (Bibiche)', 3300),
#  ('Alzing', 'Distroff (Eglise)', 3000),
#  ('Alzing', 'Bouzonville', 1200),
#  ('Alzing', 'Remelfang', 1740),
#  ('Alzing', 'Budange', 1980),
#  ('Alzing', 'Vaudreching', 420),
#  ('Alzing', 'Téterchen', 480),
#  ('Alzing', 'Kuntzig (Place liberté)', 3360),
#  ('Alzing', 'Gare de Thionville', 4140),
#  ('Alzing', 'Hestroff', 1260),
#  ('Alzing', 'Metzervisse (Eglise)', 4020),
#  ('Alzing', 'Hombourg (Tilleuls)', 3180),
#  ('Alzing', 'Kédange (Eglise)', 3420),
#  ('Alzing', 'Budange', 2160),
#  ('Alzing', 'Freistroff', 780),
#  ('Alzing', 'Hombourg (Tilleuls)', 2400),
#  ('Alzing', 'Hestroff', 1440),
#  ('Alzing', 'Metzervisse (Centre)', 2700),
#  ('Alzing', 'Hargarten-aux-Mines', 720),
#  ('Alzing', 'Yutz', 4920),
#  ('Alzing', 'Freistroff', 960),
#  ('Alzing', 'Distroff (Eglise)', 4320),
#  ('Alzing', 'Hombourg (Chapelle)', 2160),
#  ('Alzing', 'Anzeling (Carrefour)', 960),
#  ('Alzing', 'Kédange (Eglise)', 3300),
#  ('Alzing', 'Freistroff', 1920),
#  ('Alzing', 'Yutz-St-Vitus', 5040),
#  ('Alzing', 'Hombourg (Chapelle)', 2340),
#  ('Alzing', 'Aboncourt', 1800),
#  ('Alzing', 'Bouzonville', 1440),
#  ('Alzing', 'Anzeling', 1920),
#  ('Alzing', 'Anzeling (Carrefour)', 1140),
#  ('Alzing', 'Metzervisse (Centre)', 3060),
#  ('Alzing', 'Gare de Thionville', 5160),
#  ('Alzing', 'Vaudreching', 660),
#  ('Alzing', 'Kédange', 2580),
#  ('Alzing', 'Aboncourt', 1980),
#  ('Alzing', 'Anzeling', 2100),
#  ('Alzing', 'Falck (Rue principale)', 1020),
#  ('Alzing', 'Ebersviller (Centre)', 1500),
#  ('Alzing', 'Hombourg (Tilleuls)', 3420),
#  ('Alzing', 'Kuntzig (Bibiche)', 4200),
#  ('Alzing', 'Distroff (Eglise)', 3900),
#  ('Alzing', 'Metzeresche', 2820),
#  ('Alzing', 'Distroff (Eglise)', 4380),
#  ('Alzing', 'Aboncourt', 2940),
#  ('Alzing', 'Budange', 2880),
#  ('Alzing', 'Creutzwald G.R.', 1740),
#  ('Alzing', 'Vaudreching', 1320),
#  ('Alzing', 'Kuntzig (Place liberté)', 4260),
#  ('Alzing', 'Gare de Thionville', 5040),
#  ('Alzing', 'Ebersviller (Centre)', 1680),
#  ('Alzing', 'Hestroff', 2160),
#  ('Alzing', 'Kédange', 2460),
#  ('Alzing', 'Hargarten-Falck', 900),
#  ('Alzing', 'Metzervisse (Eglise)', 4140),
#  ('Alzing', 'Remelfang', 600),
#  ('Alzing', 'Budange', 3060),
#  ('Alzing', 'Freistroff', 1680),
#  ('Alzing', 'Ebersviller (Centre)', 2640),
#  ('Alzing', 'Hargarten-aux-Mines', 660),
#  ('Alzing', 'Hombourg (Tilleuls)', 3300),
#  ('Alzing', 'Bouzonville (Alzing)', 180),
#  ('Alzing', 'Hestroff', 2340),
#  ('Alzing', 'Metzervisse (Centre)', 3600),
#  ('Alzing', 'Kuntzig (Bibiche)', 4560),
#  ('Alzing', 'Metzervisse (Centre)', 4080),
#  ('Alzing', 'Anzeling', 2160),
#  ('Alzing', 'Yutz', 3600),
#  ('Alzing', 'Freistroff', 1860),
#  ('Alzing', 'Hombourg (Chapelle)', 3060),
#  ('Alzing', 'Anzeling (Carrefour)', 1860),
#  ('Alzing', 'Yutz-St-Vitus', 3720),
#  ('Alzing', 'Metzeresche', 3840),
#  ('Alzing', 'Hombourg (Chapelle)', 3240),
#  ('Alzing', 'Aboncourt', 2700),
#  ('Alzing', 'Metzervisse (Eglise)', 2760),
#  ('Alzing', 'Anzeling (Carrefour)', 2040),
#  ('Alzing', 'Gare de Thionville', 5580),
#  ('Alzing', 'Metzervisse (Centre)', 3960),
#  ('Alzing', 'Budange', 3120),
#  ('Alzing', 'Vaudreching', 1560),
#  ('Alzing', 'Kédange', 3480),
#  ('Alzing', 'Hestroff', 2400),
#  ('Alzing', 'Aboncourt', 2880),
#  ('Alzing', 'Bouzonville', 300),
#  ('Alzing', 'Ebersviller (Centre)', 2400),
#  ('Alzing', 'Remelfang', 840),
#  ('Alzing', 'Metzeresche', 3720),
#  ('Alzing', 'Hargarten-Falck', 840),
#  ('Alzing', 'Kuntzig (Place liberté)', 4680),
#  ('Alzing', 'Merten', 1320),
#  ('Alzing', 'Metzervisse (Eglise)', 3120),
#  ('Alzing', 'Ebersviller (Centre)', 2580),
#  ('Alzing', 'Kédange', 3360),
#  ('Alzing', 'Hombourg (Tilleuls)', 2280),
#  ('Alzing', 'Kédange (Eglise)', 2520),
#  ('Alzing', 'Hombourg (Chapelle)', 3300),
#  ('Alzing', 'Remelfang', 1500),
#  ('Alzing', 'Anzeling (Carrefour)', 2100),
#  ('Alzing', 'Bouzonville (Alzing)', 1080),
#  ('Alzing', 'Brettnach', 180),
#  ('Alzing', 'Yutz', 4500),
#  ('Alzing', 'Distroff (Eglise)', 3420),
#  ('Alzing', 'Kédange (Eglise)', 2400),
#  ('Alzing', 'Téterchen', 420),
#  ('Ambert', 'Allègre', 3360),
#  ('Ambert', 'Ambert-Ville', 120),
#  ('Ambert', 'Allegre-Maison-Retraite', 3420),
#  ('Ambert', 'Darsac-Lotissement', 4620),
#  ('Ambert', 'Vertolaye', 840),
#  ('Ambert', 'Pont-de-Dore-le-Chambon', 3420),
#  ('Ambert', "Céaux-d'Allègre", 3900),
#  ('Ambert', 'Gare de Le Puy-en-Velay', 6420),
#  ('Ambert', 'Gare de Darsac', 4500),
#  ('Ambert', 'Puy-Guillaume-Ville', 5460),
#  ('Ambert', 'Thiers-Ville-Mairie', 4080),
#  ('Ambert', 'Freycenet', 4740),
#  ('Ambert', 'Courpière', 2460),
#  ('Ambert', 'Le Puy-Lafayette', 6120),
#  ('Ambert', 'Le Puy-en-Velay Lafayette', 6120),
#  ('Ambert', 'Coubladour', 4920),
#  ('Ambert', 'Le Puy-en-Velay-Hermit.', 5940),
#  ('Ambert', 'Puy-Guillaume-Emmaüs', 5280),
#  ('Ambert', 'La Chaise-Dieu', 2280),
#  ('Ambert', 'Monlet', 3120),
#  ('Ambert', 'Puy-en-Velay-Hopital', 6060),
#  ('Ambert', 'Mariol', 6000),
#  ('Ambert', 'Dore-Eglise', 1440),
#  ('Ambert', 'Ambert-Ville', 240),
#  ('Ambert', 'Sembadel', 2640),
#  ('Ambert', 'Arlanc-Place-Eglise', 1140),
#  ('Ambert', 'Abrest Mairie', 6780),
#  ('Ambert', 'Gare de Pont-de-Dore', 3180),
#  ('Ambert', 'Gare de Thiers', 4380),
#  ('Ambert', 'Freyssenet', 4740),
#  ('Ambert', 'St-Yorre-Nouvel-Hotel', 6420),
#  ('Ambert', 'La-Croix-St-Bonnet', 5100),
#  ('Ambert', 'Giroux', 1740),
#  ('Ambert', 'Ris-Abris-Bus', 5820),
#  ('Ambert', 'Serres-Hte-Loire', 3600),
#  ('Ambert', 'Marsac-en-Livradois', 660),
#  ('Ambert', 'Néronde', 2820),
#  ('Ambert', 'Le-Puy-en-Velay-Fayolle', 6240),
#  ('Ambert', 'St-Yorre-Croix-des-Vern', 6300),
#  ('Ambert', 'Thiers-le-Moutier', 3780),
#  ('Ambert', 'Olliergues', 1440),
#  ('Ambert', 'Gare de Vichy', 7140),
#  ('Ambert', 'Chauprillade-(La)', 4980),
#  ('Ambert', 'Thiers-Lycée', 4560),
#  ('Ambert-Ville', 'Mariol', 5880),
#  ('Ambert-Ville', 'Gare de Darsac', 4260),
#  ('Ambert-Ville', 'Gare de Vichy', 7020),
#  ('Ambert-Ville', 'Coubladour', 4680),
#  ('Ambert-Ville', 'Thiers-Lycée', 4440),
#  ('Ambert-Ville', 'Gare de Pont-de-Dore', 3060),
#  ('Ambert-Ville', 'Le Puy-Lafayette', 5880),
#  ('Ambert-Ville', 'Puy-en-Velay-Hopital', 5820),
#  ('Ambert-Ville', 'Dore-Eglise', 1200),
#  ('Ambert-Ville', 'Pont-de-Dore-le-Chambon', 3300),
#  ('Ambert-Ville', 'Sembadel', 2400),
#  ('Ambert-Ville', 'Vertolaye', 720),
#  ('Ambert-Ville', 'Arlanc-Place-Eglise', 900),
#  ('Ambert-Ville', 'Le Puy-en-Velay-Hermit.', 5700),
#  ('Ambert-Ville', 'Ambert', 240),
#  ('Ambert-Ville', 'Monlet', 2880),
#  ('Ambert-Ville', 'Gare de Thiers', 4260),
#  ('Ambert-Ville', 'St-Yorre-Nouvel-Hotel', 6300),
#  ('Ambert-Ville', 'Courpière', 2340),
#  ('Ambert-Ville', 'La-Croix-St-Bonnet', 4980),
#  ('Ambert-Ville', 'Giroux', 1620),
#  ('Ambert-Ville', 'Freyssenet', 4500),
#  ('Ambert-Ville', 'Néronde', 2700),
#  ('Ambert-Ville', 'St-Yorre-Croix-des-Vern', 6180),
#  ('Ambert-Ville', 'Thiers-le-Moutier', 3660),
#  ('Ambert-Ville', 'Serres-Hte-Loire', 3360),
#  ('Ambert-Ville', 'Marsac-en-Livradois', 420),
#  ('Ambert-Ville', 'La Chaise-Dieu', 2040),
#  ('Ambert-Ville', 'Le-Puy-en-Velay-Fayolle', 6000),
#  ('Ambert-Ville', 'Chauprillade-(La)', 4860),
#  ('Ambert-Ville', 'Abrest Mairie', 6660),
#  ('Ambert-Ville', 'Allegre-Maison-Retraite', 3180),
#  ('Ambert-Ville', 'Allègre', 3120),
#  ('Ambert-Ville', 'Puy-Guillaume-Ville', 5340),
#  ('Ambert-Ville', 'Thiers-Ville-Mairie', 3960),
#  ('Ambert-Ville', 'Darsac-Lotissement', 4380),
#  ('Ambert-Ville', 'Gare de Le Puy-en-Velay', 6180),
#  ('Ambert-Ville', "Céaux-d'Allègre", 3660),
#  ('Ambert-Ville', 'Ris-Abris-Bus', 5700),
#  ('Ambert-Ville', 'Ambert', 120),
#  ('Ambert-Ville', 'Freycenet', 4500),
#  ('Ambert-Ville', 'Olliergues', 1320),
#  ('Ambert-Ville', 'Puy-Guillaume-Emmaüs', 5160),
#  ('Ambert-Ville', 'Le Puy-en-Velay Lafayette', 5880),
#  ('Ambronay-Priay-Rd-1075', 'Bourg-en-Bresse Gare R', 1920),
#  ('Ambronay-Priay-Rd-1075', 'St-Martin-Du-Mont-Le-Fa', 660),
#  ('Ambronay-Priay-Rd-1075', 'Bourg-En-Bresse-Archive', 1500),
#  ('Ambronay-Priay-Rd-1075', "Gare de Pont-d'Ain", 300),
#  ('Ambronay-Priay-Rd-1075', 'Gare de Ambérieu-en-Bugey', 660),
#  ('Ambronay-Priay-Rd-1075', 'La-Vavrette-Tossiat', 1020),
#  ('Ancizes-St-Georges-Bour', 'St-Gervais-Mairie', 1440),
#  ('Ancizes-St-Georges-Bour', 'St-Gervais-Mairie', 1020),
#  ('Ancizes-St-Georges-Bour', 'Gare de Volvic', 2340),
#  ('Ancizes-St-Georges-Bour', 'Paugnat-Eglise', 1860),
#  ('Ancizes-St-Georges-Bour', 'Gare de Volvic', 2400),
#  ('Ancizes-St-Georges-Bour', 'Gare de Clermont-Ferrand', 4140),
#  ('Ancizes-St-Georges-Bour', 'Paugnat-Eglise', 1920),
#  ('Ancizes-St-Georges-Bour', 'Moulet-Marcenat', 2040),
#  ('Ancizes-St-Georges-Bour', 'St-Georges-Mons-Ecoles', 900),
#  ('Ancizes-St-Georges-Bour', 'St-Eloy', 2400),
#  ('Ancizes-St-Georges-Bour', 'Ancizes-St-Georges-Usin', 480),
#  ('Ancizes-St-Georges-Bour', 'Moulet-Marcenat', 2100),
#  ('Ancizes-St-Georges-Bour', 'St-Eloy-les-Mines-Lycée', 2220),
#  ('Ancizes-St-Georges-Bour', 'St-Gervais-Ch-LPA.', 1320),
#  ('Ancizes-St-Georges-Bour', 'St-Georges-Mons-Ecoles', 840),
#  ('Ancizes-St-Georges-Usin', 'St-Eloy', 2880),
#  ('Ancizes-St-Georges-Usin', 'St-Gervais-Mairie', 1500),
#  ('Ancizes-St-Georges-Usin', 'Gare de Volvic', 1860),
#  ('Ancizes-St-Georges-Usin', 'St-Eloy-les-Mines-Lycée', 2700),
#  ('Ancizes-St-Georges-Usin', 'St-Gervais-Mairie', 1680),
#  ('Ancizes-St-Georges-Usin', 'Paugnat-Eglise', 1380),
#  ('Ancizes-St-Georges-Usin', 'Ancizes-St-Georges-Bour', 360),
#  ('Ancizes-St-Georges-Usin', 'Gare de Volvic', 1920),
#  ('Ancizes-St-Georges-Usin', 'Gare de Clermont-Ferrand', 3660),
#  ('Ancizes-St-Georges-Usin', 'Ancizes-St-Georges-Bour', 240),
#  ('Ancizes-St-Georges-Usin', 'Paugnat-Eglise', 1440),
#  ('Ancizes-St-Georges-Usin', 'Moulet-Marcenat', 1560),
#  ('Ancizes-St-Georges-Usin', 'St-Georges-Mons-Ecoles', 420),
#  ('Ancizes-St-Georges-Usin', 'Moulet-Marcenat', 1620),
#  ('Ancizes-St-Georges-Usin', 'Ancizes-St-Georges-Bour', 480),
#  ('Ancizes-St-Georges-Usin', 'St-Georges-Mons-Ecoles', 360),
#  ('Ancizes-St-Georges-Usin', 'St-Gervais-Ch-LPA.', 1560),
#  ('Andelat', 'Gare de St-Flour-Chaudes-Aigues', 480),
#  ('Andelat', 'Gare de St-Flour-Chaudes-Aigues', 660),
#  ('Andelat', 'Talizat', 960),
#  ('Andelat', 'St-Flour-les-Allées', 120),
#  ('Andelat', 'Talizat', 840),
#  ('Andelat', 'Gare de Neussargues', 1260),
#  ('Andelat', 'Roueyre', 240),
#  ('Andelat', 'Talizat', 900),
#  ('Andelat', 'Gare de Neussargues', 1320),
#  ('Andelat', 'Roueyre', 120),
#  ('Andelat', 'St-Flour-les-Allées', 240),
#  ('Andelat', "Gare de St-Chély-d'Apcher", 1980),
#  ('Andelat', "Gare de St-Chély-d'Apcher", 2460),
#  ('Andelat', 'Gare de St-Flour-Chaudes-Aigues', 420),
#  ('Andelat', 'Gare de St-Flour-Chaudes-Aigues', 600),
#  ('Annonay-Gare-Route', "St-Martin-d'Hères", 9600),
#  ('Annonay-Gare-Route', 'Grenoble-Gare-Routière', 8100),
#  ('Annonay-Gare-Route', 'Tournon-Centre', 2400),
#  ('Annonay-Gare-Route', 'Gare de Valence-TGV', 4500),
#  ('Annonay-Gare-Route', 'Gare de Tain', 3000),
#  ('Anos-31', 'Chaum-Pont', 600),
#  ('Anos-31', 'Marignac-St-Béat', 480),
#  ('Anos-31', 'Antignac (Hte-Garonne)', 540),
#  ('Anos-31', 'Cazaux-Layrisse', 300),
#  ('Anos-31', 'Bertren-Abri', 1200),
#  ('Anos-31', 'Chaum-Pont', 660),
#  ('Anos-31', 'Luchon', 720),
#  ('Anos-31', 'Salechan-Emb', 840),
#  ('Anos-31', 'Lège', 240),
#  ('Anos-31', 'Luchon-Richelieu', 1200),
#  ('Anos-31', 'Marignac-St-Béat', 420),
#  ('Anos-31', 'Labroq.-St-Bert.-de-Com', 1620),
#  ('Anos-31', 'Gare de Montréjeau-Gourdan-Pol.', 2160),
#  ('Anos-31', 'Siradan', 960),
#  ('Anos-31', 'Bertren-Nord', 1260),
#  ('Anos-31', 'Gaud', 180),
#  ('Anos-31', 'Cier-de-Luchon', 360),
#  ('Anos-31', 'Luchon', 780),
#  ('Anos-31', 'Loures-Barousse', 1500),
#  ('Anos-31', 'Seilhan-Le-Bazert', 1860),
#  ('Anos-31', 'Moustajon', 660),
#  ('Anos-31', 'Pratviel-la-Ferme', 420),
#  ('Anos-31', 'Bagiry', 1020),
#  ('Anos-31', 'Luscan-Pont', 1320),
#  ('Anos-31', 'Lège', 180),
#  ('Anos-31', 'Estenos', 720),
#  ('Anos-31', 'Cierp', 240),
#  ('Anos-31', 'Le-Rouziet-ParcAventure', 540),
#  ('Anos-31', 'PONT DE GURAN', 120),
#  ('Anos-31', 'Seilhan-Le-Bazert', 1920),
#  ('Anos-31', 'Galié', 1080),
#  ('Anos-31', 'Bertren-Sud', 1140),
#  ('Anos-31', 'Cier-de-Luchon', 300),
#  ('Anos-31', 'Luscan-Pont', 1380),
#  ('Anos-31', 'Gouaux-de-Luchon', 420),
#  ('Anos-31', 'Gourdan-Polignan-Lycée', 1980),
#  ('Anos-31', 'Moustajon', 600),
#  ('Anos-31', 'Pratviel-la-Ferme', 360),
#  ('Anos-31', 'Antignac (Hte-Garonne)', 480),
#  ('Anos-31', 'Cazaux-Layrisse', 240),
#  ('Anos-31', 'Gouaux-de-Luchon', 480),
#  ('Anos-31', 'Saléchan-Siradan', 900),
#  ('Anos-31', 'PONT DE GURAN', 60),
#  ('Anos-31', 'Loures-Barbazan', 1440),
#  ('Anos-31', 'Muna-Burgalays', 60),
#  ('Anse-(Monument)', 'Collonges-F.-Tcl-Gar', 1500),
#  ('Anse-(Monument)', 'Albigny-Neuville-Arret', 900),
#  ('Anse-(Monument)', 'Lyon-Perrache-Gare-Rout', 3300),
#  ('Anse-(Monument)', "Gare de St-Germain-au-Mont-d'Or", 600),
#  ('Anse-(Monument)', 'Gare de Quincieux', 300),
#  ('Anse-(Monument)', 'Lyon-Vaise-Gare-Routièr', 2400),
#  ('Anse-(Monument)', "Couzon-Au-Mont-D'or-Arr", 1200),
#  ('Antignac (Hte-Garonne)', 'PONT DE GURAN', 420),
#  ('Antignac (Hte-Garonne)', 'Gare de Montréjeau-Gourdan-Pol.', 2760),
#  ('Antignac (Hte-Garonne)', 'Siradan', 1560),
#  ('Antignac (Hte-Garonne)', 'Cier-de-Luchon', 180),
#  ('Antignac (Hte-Garonne)', 'Luchon', 240),
#  ('Antignac (Hte-Garonne)', 'Loures-Barbazan', 2040),
#  ('Antignac (Hte-Garonne)', 'Chaum-Pont', 1200),
#  ('Antignac (Hte-Garonne)', 'Le-Rouziet-ParcAventure', 1140),
#  ('Antignac (Hte-Garonne)', 'Anos-31', 600),
#  ('Antignac (Hte-Garonne)', 'Bertren-Abri', 1800),
#  ('Antignac (Hte-Garonne)', 'Pratviel-la-Ferme', 120),
#  ('Antignac (Hte-Garonne)', 'Seilhan-Le-Bazert', 2520),
#  ('Antignac (Hte-Garonne)', 'Marignac-St-Béat', 1080),
#  ('Antignac (Hte-Garonne)', 'Galié', 1680),
#  ('Antignac (Hte-Garonne)', 'Luchon-Richelieu', 660),
#  ('Antignac (Hte-Garonne)', 'Gouaux-de-Luchon', 60),
#  ('Antignac (Hte-Garonne)', 'Chaum-Pont', 1260),
#  ('Antignac (Hte-Garonne)', 'Lège', 360),
#  ('Antignac (Hte-Garonne)', 'Salechan-Emb', 1440),
#  ('Antignac (Hte-Garonne)', 'Luscan-Pont', 1980),
#  ('Antignac (Hte-Garonne)', 'Moustajon', 60),
#  ('Antignac (Hte-Garonne)', 'Bertren-Nord', 1860),
#  ('Antignac (Hte-Garonne)', 'Luchon-Richelieu', 720),
#  ('Antignac (Hte-Garonne)', 'Gaud', 780),
#  ('Antignac (Hte-Garonne)', 'Loures-Barousse', 2100),
#  ('Antignac (Hte-Garonne)', 'Saléchan-Siradan', 1500),
#  ('Antignac (Hte-Garonne)', 'Seilhan-Le-Bazert', 2460),
#  ('Antignac (Hte-Garonne)', 'Marignac-St-Béat', 1020),
#  ('Antignac (Hte-Garonne)', 'Labroq.-St-Bert.-de-Com', 2220),
#  ('Antignac (Hte-Garonne)', 'Moustajon', 120),
#  ('Antignac (Hte-Garonne)', 'Cazaux-Layrisse', 240),
#  ('Antignac (Hte-Garonne)', 'Muna-Burgalays', 660),
#  ('Antignac (Hte-Garonne)', 'Luscan-Pont', 1920),
#  ('Antignac (Hte-Garonne)', 'Estenos', 1320),
#  ('Antignac (Hte-Garonne)', 'Cierp', 840),
#  ('Antignac (Hte-Garonne)', 'Bagiry', 1620),
#  ('Antignac (Hte-Garonne)', 'Gourdan-Polignan-Lycée', 2580),
#  ('Antignac (Hte-Garonne)', 'Luchon', 180),
#  ('Antignac (Hte-Garonne)', 'Bertren-Sud', 1740),
#  ('Anzeling', 'Merten-République', 2160),
#  ('Anzeling', 'Falck (Rue principale)', 2940),
#  ('Anzeling', 'Creutzwald G.R.', 3480),
#  ('Anzeling', 'Gare de Thionville', 3240),
#  ('Anzeling', 'Yutz-St-Vitus', 2700),
#  ('Anzeling', 'Metzervisse (Eglise)', 1740),
#  ('Anzeling', 'Metzeresche', 1680),
#  ('Anzeling', 'Yutz', 2580),
#  ('Anzeling', 'Vaudreching', 540),
#  ('Anzeling', 'Creutzwald G.R.', 3660),
#  ('Anzeling', 'Gare de Thionville', 3420),
#  ('Anzeling', 'Yutz-St-Vitus', 2880),
#  ('Anzeling', 'Alzing', 1740),
#  ('Anzeling', 'Metzervisse (Eglise)', 1920),
#  ('Anzeling', 'Kédange (Eglise)', 1320),
#  ('Anzeling', 'Yutz', 2760),
#  ('Anzeling', 'Alzing', 1920),
#  ('Anzeling', 'Merten', 2340),
#  ('Anzeling', 'Distroff (Eglise)', 2040),
#  ('Anzeling', 'Metzervisse (Eglise)', 1980),
#  ('Anzeling', 'Remelfang', 300),
#  ('Anzeling', 'Falck (Rue principale)', 1920),
#  ('Anzeling', 'Merten', 2220),
#  ('Anzeling', 'Kédange (Eglise)', 1380),
#  ('Anzeling', 'Distroff (Eglise)', 2220),
#  ('Anzeling', 'Hargarten-Falck', 2580),
#  ('Anzeling', 'Merten-République', 2280),
#  ('Anzeling', 'Remelfang', 480),
#  ('Anzeling', 'Creutzwald G.R.', 2640),
#  ('Anzeling', 'Hargarten-Falck', 2760),
#  ('Anzeling', 'Kuntzig (Bibiche)', 2280),
#  ('Anzeling', 'Brettnach', 1080),
#  ('Anzeling', 'Hargarten-aux-Mines', 1560),
#  ('Anzeling', 'Merten', 3060),
#  ('Anzeling', 'Budange', 960),
#  ('Anzeling', 'Remelfang', 360),
#  ('Anzeling', 'Bouzonville (Alzing)', 720),
#  ('Anzeling', 'Metzervisse (Centre)', 1920),
#  ('Anzeling', 'Téterchen', 1320),
#  ('Anzeling', 'Brettnach', 1260),
#  ('Anzeling', 'Hestroff', 240),
#  ('Anzeling', 'Hargarten-aux-Mines', 1740),
#  ('Anzeling', 'Anzeling (Carrefour)', 60),
#  ('Anzeling', 'Merten', 3240),
#  ('Anzeling', 'Bouzonville (Alzing)', 900),
#  ('Anzeling', 'Distroff (Eglise)', 1980),
#  ('Anzeling', 'Freistroff', 240),
#  ('Anzeling', 'Téterchen', 1500),
#  ('Anzeling', 'Gare de Thionville', 2940),
#  ('Anzeling', 'Hargarten-aux-Mines', 2400),
#  ('Anzeling', 'Merten-République', 3000),
#  ('Anzeling', 'Hombourg (Tilleuls)', 1200),
#  ('Anzeling', 'Kuntzig (Place liberté)', 2340),
#  ('Anzeling', 'Bouzonville', 720),
#  ('Anzeling', 'Téterchen', 2160),
#  ('Anzeling', 'Brettnach', 2100),
#  ('Anzeling', 'Bouzonville (Alzing)', 780),
#  ('Anzeling', 'Kédange', 1380),
#  ('Anzeling', 'Falck (Rue principale)', 2040),
#  ('Anzeling', 'Hargarten-aux-Mines', 2580),
#  ('Anzeling', 'Merten-République', 3180),
#  ('Anzeling', 'Aboncourt', 780),
#  ('Anzeling', 'Brettnach', 1800),
#  ('Anzeling', 'Kuntzig (Bibiche)', 2220),
#  ('Anzeling', 'Hargarten-Falck', 1740),
#  ('Anzeling', 'Kuntzig (Place liberté)', 2520),
#  ('Anzeling', 'Metzervisse (Centre)', 1680),
#  ('Anzeling', 'Téterchen', 2340),
#  ('Anzeling', 'Creutzwald G.R.', 2760),
#  ('Anzeling', 'Freistroff', 300),
#  ('Anzeling', 'Hombourg (Chapelle)', 1140),
#  ('Anzeling', 'Ebersviller (Centre)', 480),
#  ('Anzeling', 'Kuntzig (Bibiche)', 2400),
#  ('Anzeling', 'Hargarten-Falck', 1920),
#  ('Anzeling', 'Metzervisse (Centre)', 1860),
#  ('Anzeling', 'Hombourg (Tilleuls)', 1260),
#  ('Anzeling', 'Bouzonville', 780),
#  ('Anzeling', 'Alzing', 1020),
#  ('Anzeling', 'Kédange', 1440),
#  ('Anzeling', 'Metzeresche', 1620),
#  ('Anzeling', 'Vaudreching', 480),
#  ('Anzeling', 'Falck (Rue principale)', 2760),
#  ('Anzeling', 'Bouzonville', 660),
#  ('Anzeling', 'Alzing', 900),
#  ('Anzeling', 'Vaudreching', 660),
#  ('Anzeling (Carrefour)', 'Metzervisse (Centre)', 1980),
#  ('Anzeling (Carrefour)', 'Anzeling', 60),
#  ('Anzeling (Carrefour)', 'Creutzwald G.R.', 2700),
#  ('Anzeling (Carrefour)', 'Gare de Thionville', 3300),
#  ('Anzeling (Carrefour)', 'Freistroff', 240),
#  ('Anzeling (Carrefour)', 'Falck (Rue principale)', 1860),
#  ('Anzeling (Carrefour)', 'Gare de Thionville', 3000),
#  ('Anzeling (Carrefour)', 'Bouzonville', 600),
#  ('Anzeling (Carrefour)', 'Bouzonville (Alzing)', 660),
#  ('Anzeling (Carrefour)', 'Gare de Thionville', 3480),
#  ('Anzeling (Carrefour)', 'Budange', 1020),
#  ('Anzeling (Carrefour)', 'Hombourg (Tilleuls)', 1260),
#  ('Anzeling (Carrefour)', 'Creutzwald G.R.', 2580),
#  ('Anzeling (Carrefour)', 'Kuntzig (Place liberté)', 2400),
#  ('Anzeling (Carrefour)', 'Hestroff', 300),
#  ('Anzeling (Carrefour)', 'Bouzonville (Alzing)', 840),
#  ('Anzeling (Carrefour)', 'Hargarten-aux-Mines', 1500),
#  ('Anzeling (Carrefour)', 'Kuntzig (Place liberté)', 2580),
#  ('Anzeling (Carrefour)', 'Falck (Rue principale)', 2700),
#  ('Anzeling (Carrefour)', 'Alzing', 840),
#  ('Anzeling (Carrefour)', 'Bouzonville', 660),
#  ('Anzeling (Carrefour)', 'Hombourg (Chapelle)', 1200),
#  ('Anzeling (Carrefour)', 'Hargarten-aux-Mines', 1680),
#  ('Anzeling (Carrefour)', 'Falck (Rue principale)', 2880),
#  ('Anzeling (Carrefour)', 'Creutzwald G.R.', 3420),
#  ('Anzeling (Carrefour)', 'Kédange', 1440),
#  ('Anzeling (Carrefour)', 'Hargarten-Falck', 1680),
#  ('Anzeling (Carrefour)', 'Freistroff', 180),
#  ('Anzeling (Carrefour)', 'Merten', 2280),
#  ('Anzeling (Carrefour)', 'Vaudreching', 480),
#  ('Anzeling (Carrefour)', 'Creutzwald G.R.', 3600),
#  ('Anzeling (Carrefour)', 'Hargarten-aux-Mines', 2340),
#  ('Anzeling (Carrefour)', 'Metzeresche', 1680),
#  ('Anzeling (Carrefour)', 'Hargarten-Falck', 1860),
#  ('Anzeling (Carrefour)', 'Hargarten-aux-Mines', 2520),
#  ('Anzeling (Carrefour)', 'Bouzonville', 720),
#  ('Anzeling (Carrefour)', 'Merten', 2160),
#  ('Anzeling (Carrefour)', 'Hargarten-Falck', 2520),
#  ('Anzeling (Carrefour)', 'Merten-République', 2220),
#  ('Anzeling (Carrefour)', 'Kédange', 1500),
#  ('Anzeling (Carrefour)', 'Metzervisse (Eglise)', 1800),
#  ('Anzeling (Carrefour)', 'Hargarten-Falck', 2700),
#  ('Anzeling (Carrefour)', 'Metzeresche', 1740),
#  ('Anzeling (Carrefour)', 'Yutz', 2640),
#  ('Anzeling (Carrefour)', 'Brettnach', 1020),
#  ('Anzeling (Carrefour)', 'Distroff (Eglise)', 2040),
#  ('Anzeling (Carrefour)', 'Alzing', 960),
#  ('Anzeling (Carrefour)', 'Merten-République', 2100),
#  ('Anzeling (Carrefour)', 'Metzervisse (Eglise)', 1980),
#  ('Anzeling (Carrefour)', 'Merten', 3000),
#  ('Anzeling (Carrefour)', 'Remelfang', 300),
#  ('Anzeling (Carrefour)', 'Yutz', 2820),
#  ('Anzeling (Carrefour)', 'Téterchen', 1260),
#  ('Anzeling (Carrefour)', 'Brettnach', 1200),
#  ('Anzeling (Carrefour)', 'Vaudreching', 420),
#  ('Anzeling (Carrefour)', 'Yutz-St-Vitus', 2760),
#  ('Anzeling (Carrefour)', 'Merten', 3180),
#  ('Anzeling (Carrefour)', 'Téterchen', 1440),
#  ('Anzeling (Carrefour)', 'Vaudreching', 600),
#  ('Anzeling (Carrefour)', 'Kuntzig (Bibiche)', 2280),
#  ...]

# %%
# list of unique stops
stopNamesList = x[['stop_name']].dropna().drop_duplicates()
stopNamesList
# Out:
#                            stop_name
# 0                   Gare de Le Havre
# 1         Gare de Bréauté-Beuzeville
# 2                     Gare de Yvetot
# 3          Gare de Rouen-Rive-Droite
# 4            Gare de Paris-St-Lazare
# ...                              ...
# 206818              Gare de Xertigny
# 207631              Gare de Cousance
# 207827      Gare de Domblans-Voiteur
# 208578     Gare de Torpes-Boussières
# 208579  Gare de Montferrand-Thoraise
#
# [3841 rows x 1 columns]

# %% [markdown]
# ## We save all stopnames, and graph segments to the cloud DB

# %%
###########################################
# SAVE TO DB, LAUNCH ONLY ONCE (DONE)
###########################################
"""
# inssert items in mongo atlas DB
client = pymongo.MongoClient("mongodb+srv://admin:admin@clusteria.tvj6u.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client['iadb']
dataset3 = db['stopNames']
dataset4 = db['graphSegments']

import json
# to load data into mongodb
stopNamesList.index = stopNamesList.index.map(str)
g=[]
for index, row in stopNamesList.iterrows():
    g.append(row.to_dict())

    
g2 = []
for row in theList:
    aa = {'from':row[0],'to':row[1],'time':row[2]}
    g2.append(aa)
g2

x = dataset3.insert_many(g)
x = dataset4.insert_many(g2)
"""
# Out:
# '\n# inssert items in mongo atlas DB\nclient = pymongo.MongoClient("mongodb+srv://admin:admin@clusteria.tvj6u.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")\ndb = client[\'iadb\']\ndataset3 = db[\'stopNames\']\ndataset4 = db[\'graphSegments\']\n\nimport json\n# to load data into mongodb\nstopNamesList.index = stopNamesList.index.map(str)\ng=[]\nfor index, row in stopNamesList.iterrows():\n    g.append(row.to_dict())\n\n    \ng2 = []\nfor row in theList:\n    aa = {\'from\':row[0],\'to\':row[1],\'time\':row[2]}\n    g2.append(aa)\ng2\n\nx = dataset3.insert_many(g)\nx = dataset4.insert_many(g2)\n'
